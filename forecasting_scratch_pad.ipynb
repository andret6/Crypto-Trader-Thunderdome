# %%
# Pull data 

API_KEY = os.getenv("COINGECKO_API_KEY")  # REQUIRED
assert API_KEY, "Set COINGECKO_API_KEY in your environment."

BASE = "https://pro-api.coingecko.com/api/v3"   # Pro endpoint only
VS = "usd"

# ---- rate limiting (tune to your Pro plan) ----
CALLS_PER_MIN = 200
SLEEP_SEC = 60.0 / CALLS_PER_MIN

def _get(url, params=None, max_retries=3):
    headers = {"x-cg-pro-api-key": API_KEY}
    for i in range(max_retries):
        r = requests.get(url, params=params, headers=headers, timeout=30)
        if r.status_code == 200:
            return r.json()
        if r.status_code in (429, 500, 502, 503, 504):
            time.sleep(SLEEP_SEC * (i+1) * 2)
            continue
        r.raise_for_status()
    raise RuntimeError(f"GET failed: {url} {r.status_code} {r.text[:200]}")

def list_top_coins(n=300, vs=VS):
    out, page = [], 1
    while len(out) < n:
        params = dict(vs_currency=vs, order="market_cap_desc",
                      per_page=250, page=page, price_change_percentage="24h")
        data = _get(f"{BASE}/coins/markets", params=params)
        if not data: break
        out.extend([{"id": c["id"], "symbol": c["symbol"], "name": c["name"]} for c in data])
        page += 1
        time.sleep(SLEEP_SEC)
    return out[:n]

def market_chart_close(coin_id, days, vs=VS):
    """
    /coins/{id}/market_chart
    Granularity is automatic: ~5min for last day, hourly up to 90d, daily beyond.
    """
    params = dict(vs_currency=vs, days=days)
    data = _get(f"{BASE}/coins/{coin_id}/market_chart", params=params)
    time.sleep(SLEEP_SEC)
    df = pd.DataFrame(data.get("prices", []), columns=["timestamp_ms", "close"])
    if df.empty:
        return df
    df["timestamp"] = pd.to_datetime(df["timestamp_ms"], unit="ms", utc=True)
    df = df.drop(columns=["timestamp_ms"]).set_index("timestamp").sort_index()
    df = df[~df.index.duplicated(keep="last")]
    return df

# ---------- Daily (max history) ----------
def fetch_daily_max(coin_id):
    df = market_chart_close(coin_id, days="max")
    if df.empty:
        return df
    # Strict daily at 00:00 UTC; last sample per day
    return df.resample("1D").last().dropna()

# ---------- 5-minute RETURNS (last ~24h) ----------
def fetch_5min_returns_last_day(coin_id, log_returns=False):
    """
    Build a strict 5-minute grid from last ~1 day native samples (~5m),
    then compute returns on that 5-minute grid.
    - Simple returns: pct_change()
    - Log returns: diff(log(price))
    """
    df1 = market_chart_close(coin_id, days=1)  # native ~5m stamps (irregular)
    if df1.empty:
        return df1

    # Align to exact 5-minute grid using last observed close within each bin.
    m5_close = df1.resample("5min").last()

    # Drop leading/trailing bins with no data at all
    m5_close = m5_close.loc[df1.index.min():df1.index.max()].dropna(how="all")

    if m5_close.empty:
        return m5_close  # nothing to compute

    if log_returns:
        # log returns: ln(P_t) - ln(P_{t-1})
        m5_ret = (m5_close.apply(lambda s: pd.Series(pd.Series(s).apply(lambda v: None if pd.isna(v) else v)))  # no-op, keeps dtype stable
                  .apply(lambda col: (col.apply(lambda v: pd.NA if pd.isna(v) else v)).astype(float)))
        m5_ret = (m5_close["close"].apply(lambda v: None if pd.isna(v) else v)).astype(float)
        m5_ret = pd.Series(m5_ret, index=m5_close.index).apply(lambda x: pd.NA if pd.isna(x) else x)
        m5_ret = pd.Series(pd.Series(m5_close["close"]).astype(float)).apply(lambda x: x)
        # Simpler, clearer:
        import numpy as np
        m5_ret = pd.Series(np.log(m5_close["close"]), index=m5_close.index).diff().to_frame(name="return")
    else:
        # simple percentage returns
        m5_ret = m5_close["close"].pct_change().to_frame(name="return")

    # Drop the first NaN return
    m5_ret = m5_ret.dropna()
    return m5_ret

def fetch_many(top_n=50, log_returns=False):
    coins = list_top_coins(n=top_n)
    out = {}
    for c in coins:
        cid = c["id"]
        try:
            daily = fetch_daily_max(cid)
            m5_returns = fetch_5min_returns_last_day(cid, log_returns=log_returns)
            out[cid] = {
                "meta": c,
                "daily": daily,
                "m5_returns": m5_returns,   # column name 'return'
            }
            print(f"OK {cid:20s}  m5_ret={len(m5_returns):5d}  daily={len(daily):6d}")
        except Exception as e:
            print(f"ERR {cid}: {e}")
    return out

# ---------- Main: wide pivots & saves (DAILY + 5-MIN RETURNS) ----------
if __name__ == "__main__":
    TOP_N = 250
    LOG_RETURNS = False   # set True for log returns

    data = fetch_many(top_n=TOP_N, log_returns=LOG_RETURNS)
    keep = list(data.keys())[:TOP_N]

    # Wide DAILY closes
    wide_daily = pd.concat(
        [data[cid]["daily"].rename(columns={"close": cid}) for cid in keep if not data[cid]["daily"].empty],
        axis=1
    ).sort_index()

    wide_daily = wide_daily.sort_index().ffill()  # Fill NA values
    
    wide_daily.to_parquet("coingecko_daily_close_topN.parquet")

    # Wide 5-MIN RETURNS (last ~24h)
    wide_5m_returns = pd.concat(
        [data[cid]["m5_returns"].rename(columns={"return": cid}) for cid in keep if not data[cid]["m5_returns"].empty],
        axis=1
    ).sort_index()

    # Drop timestamps where all coins are NaN (edge bins)
    wide_5m_returns = wide_5m_returns.dropna(how="all")

    wide_5m_returns = wide_5m_returns.sort_index().ffill()  # Fill NA values

    wide_5m_returns.to_parquet("coingecko_5min_returns_topN.parquet")

    print("DAILY tail:\n", wide_daily.tail())
    print("5-MIN RETURNS tail:\n", wide_5m_returns.tail())
# Out:
# OK bitcoin               m5_ret=  283  daily=  4496
# OK ethereum              m5_ret=  282  daily=  3666
# OK ripple                m5_ret=  284  daily=  4395
# OK tether                m5_ret=  282  daily=  3807
# OK binancecoin           m5_ret=  282  daily=  2894
# OK solana                m5_ret=  283  daily=  1958
# OK usd-coin              m5_ret=  281  daily=  2512
# OK staked-ether          m5_ret=  282  daily=  1703
# OK tron                  m5_ret=  282  daily=  2842
# OK dogecoin              m5_ret=  283  daily=  4264
# OK cardano               m5_ret=  283  daily=  2864
# OK chainlink             m5_ret=  282  daily=  2842
# OK wrapped-steth         m5_ret=  283  daily=  1414
# OK wrapped-bitcoin       m5_ret=  285  daily=  2393
# OK hyperliquid           m5_ret=  283  daily=   265
# OK wrapped-beacon-eth    m5_ret=  284  daily=   842
# OK stellar               m5_ret=  284  daily=  4027
# OK sui                   m5_ret=  282  daily=   841
# OK ethena-usde           m5_ret=  283  daily=   614
# OK wrapped-eeth          m5_ret=  283  daily=   596
# OK bitcoin-cash          m5_ret=  282  daily=  2941
# OK hedera-hashgraph      m5_ret=  284  daily=  2164
# OK avalanche-2           m5_ret=  283  daily=  1794
# OK weth                  m5_ret=  283  daily=  2735
# OK leo-token             m5_ret=  283  daily=  2284
# OK litecoin              m5_ret=  284  daily=  4496
# OK the-open-network      m5_ret=  283  daily=  1455
# OK usds                  m5_ret=  283  daily=   330
# OK shiba-inu             m5_ret=  283  daily=  1832
# OK binance-bridged-usdt-bnb-smart-chain  m5_ret=  281  daily=   563
# OK whitebit              m5_ret=  283  daily=  1078
# OK uniswap               m5_ret=  282  daily=  1799
# OK polkadot              m5_ret=  283  daily=  1828
# OK coinbase-wrapped-btc  m5_ret=  282  daily=   343
# OK ethena-staked-usde    m5_ret=  282  daily=   519
# OK bitget-token          m5_ret=  282  daily=  1464
# OK monero                m5_ret=  281  daily=  4108
# OK crypto-com-chain      m5_ret=  282  daily=  2423
# OK mantle                m5_ret=  282  daily=   766
# OK pepe                  m5_ret=  284  daily=   856
# OK aave                  m5_ret=  281  daily=  1783
# OK ethena                m5_ret=  283  daily=   506
# OK dai                   m5_ret=  283  daily=  2102
# OK bittensor             m5_ret=  282  daily=   902
# OK ethereum-classic      m5_ret=  283  daily=  3315
# OK near                  m5_ret=  285  daily=  1772
# OK aptos                 m5_ret=  282  daily=  1037
# OK ondo-finance          m5_ret=  283  daily=   581
# OK internet-computer     m5_ret=  282  daily=  1564
# OK pi-network            m5_ret=  281  daily=   182
# OK jito-staked-sol       m5_ret=  281  daily=  1024
# OK okb                   m5_ret=  282  daily=  2632
# OK arbitrum              m5_ret=  283  daily=   882
# OK binance-peg-weth      m5_ret=  280  daily=   379
# OK blackrock-usd-institutional-digital-liquidity-fund  m5_ret=  252  daily=   190
# OK kaspa                 m5_ret=  283  daily=  1184
# OK usd1-wlfi             m5_ret=  281  daily=   132
# OK polygon-ecosystem-token  m5_ret=  282  daily=   666
# OK algorand              m5_ret=  282  daily=  2253
# OK cosmos                m5_ret=  285  daily=  2370
# OK gatechain-token       m5_ret=  280  daily=  2310
# OK vechain               m5_ret=  282  daily=  2582
# OK fasttoken             m5_ret=  281  daily=   942
# OK rocket-pool-eth       m5_ret=  282  daily=  1367
# OK susds                 m5_ret=  281  daily=   251
# OK binance-staked-sol    m5_ret=  283  daily=   343
# OK pudgy-penguins        m5_ret=  284  daily=   247
# OK render-token          m5_ret=  281  daily=  1893
# OK jupiter-perpetuals-liquidity-provider-token  m5_ret=  280  daily=   638
# OK sei-network           m5_ret=  282  daily=   737
# OK kelp-dao-restaked-eth  m5_ret=  281  daily=   587
# OK official-trump        m5_ret=  283  daily=   215
# OK fetch-ai              m5_ret=  283  daily=  2365
# OK worldcoin-wld         m5_ret=  282  daily=   759
# OK bfusd                 m5_ret=  274  daily=     7
# OK story-2               m5_ret=  281  daily=   189
# OK bonk                  m5_ret=  282  daily=   966
# OK flare-networks        m5_ret=  282  daily=   954
# OK usdt0                 m5_ret=  282  daily=   210
# OK filecoin              m5_ret=  283  daily=  1771
# OK stakewise-v3-oseth    m5_ret=  280  daily=   619
# OK kucoin-shares         m5_ret=  281  daily=  2842
# OK lombard-staked-btc    m5_ret=  282  daily=   357
# OK quant-network         m5_ret=  283  daily=  2609
# OK liquid-staked-ethereum  m5_ret=  281  daily=   898
# OK jupiter-exchange-solana  m5_ret=  282  daily=   568
# OK sky                   m5_ret=  281  daily=   330
# OK usdtb                 m5_ret=  283  daily=   246
# OK xdce-crowd-sale       m5_ret=  282  daily=  2685
# OK polygon-bridged-usdt-polygon  m5_ret=  282  daily=   563
# OK falcon-finance        m5_ret=  281  daily=   179
# OK hash-2                m5_ret=  284  daily=    84
# OK injective-protocol    m5_ret=  281  daily=  1765
# OK kinetic-staked-hype   m5_ret=  281  daily=    36
# OK spx6900               m5_ret=  282  daily=   723
# OK mantle-staked-ether   m5_ret=  281  daily=   622
# OK celestia              m5_ret=  281  daily=   660
# OK tether-gold           m5_ret=  281  daily=  2034
# OK nexo                  m5_ret=  278  daily=  2667
# OK optimism              m5_ret=  283  daily=  1178
# OK renzo-restaked-eth    m5_ret=  283  daily=   574
# OK first-digital-usd     m5_ret=  281  daily=   757
# OK paypal-usd            m5_ret=  281  daily=   732
# OK curve-dao-token       m5_ret=  280  daily=  1833
# OK blockstack            m5_ret=  283  daily=  2126
# OK solv-btc              m5_ret=  282  daily=   501
# OK lido-dao              m5_ret=  282  daily=  1689
# OK wbnb                  m5_ret=  281  daily=  1792
# OK aerodrome-finance     m5_ret=  283  daily=   705
# OK pump-fun              m5_ret=  281  daily=    38
# OK jupiter-staked-sol    m5_ret=  280  daily=   478
# OK immutable-x           m5_ret=  280  daily=  1385
# OK saros-finance         m5_ret=  281  daily=   580
# OK binance-bridged-usdc-bnb-smart-chain  m5_ret=  281  daily=   554
# OK sonic-3               m5_ret=  281  daily=   229
# OK floki                 m5_ret=  280  daily=  1515
# OK syrupusdc             m5_ret=  281  daily=   172
# OK the-graph             m5_ret=  282  daily=  1708
# OK arbitrum-bridged-wbtc-arbitrum-one  m5_ret=  281  daily=   382
# OK pax-gold              m5_ret=  283  daily=  2166
# OK super-oeth            m5_ret=  281  daily=   357
# OK pancakeswap-token     m5_ret=  280  daily=  1787
# OK clbtc                 m5_ret=  239  daily=   199
# OK fartcoin              m5_ret=  282  daily=   304
# OK pendle                m5_ret=  281  daily=  1576
# OK conflux-token         m5_ret=  281  daily=  1745
# OK raydium               m5_ret=  281  daily=  1642
# OK kaia                  m5_ret=  281  daily=   297
# OK l2-standard-bridged-weth-base  m5_ret=  281  daily=   366
# OK tezos                 m5_ret=  282  daily=  2606
# OK msol                  m5_ret=  281  daily=  1429
# OK dogwifcoin            m5_ret=  281  daily=   617
# OK ethereum-name-service  m5_ret=  281  daily=  1381
# OK cgeth-hashkey-cloud   m5_ret=  282  daily=   199
# OK virtual-protocol      m5_ret=  282  daily=   602
# OK vaulta                m5_ret=  277  daily=    85
# OK theta-token           m5_ret=  281  daily=  2766
# OK iota                  m5_ret=  281  daily=  2990
# OK ether-fi-staked-eth   m5_ret=  281  daily=   561
# OK memecore              m5_ret=  284  daily=    49
# OK jasmycoin             m5_ret=  281  daily=  1548
# OK gala                  m5_ret=  281  daily=  1800
# OK newton-project        m5_ret=  285  daily=  2317
# OK ousg                  m5_ret=  249  daily=   689
# OK ondo-us-dollar-yield  m5_ret=  281  daily=   652
# OK usdx-money-usdx       m5_ret=  284  daily=   329
# OK morpho                m5_ret=  283  daily=   274
# OK mantle-restaked-eth   m5_ret=  280  daily=   297
# OK the-sandbox           m5_ret=  283  daily=  1833
# OK tbtc                  m5_ret=  281  daily=  1793
# OK ripple-usd            m5_ret=  281  daily=   247
# OK pyth-network          m5_ret=  284  daily=   640
# OK arbitrum-bridged-weth-arbitrum-one  m5_ret=  283  daily=   371
# OK bittorrent            m5_ret=  282  daily=  1308
# OK stader-ethx           m5_ret=  280  daily=   772
# OK walrus-2              m5_ret=  283  daily=   147
# OK jito-governance-token  m5_ret=  283  daily=   623
# OK vision-3              m5_ret=  283  daily=    36
# OK coinbase-wrapped-staked-eth  m5_ret=  283  daily=  1092
# OK zcash                 m5_ret=  284  daily=  3218
# OK flow                  m5_ret=  283  daily=  1667
# OK usual-usd             m5_ret=  282  daily=   407
# OK build-on              m5_ret=  279  daily=    91
# OK bitcoin-avalanche-bridged-btc-b  m5_ret=  280  daily=  1156
# OK sweth                 m5_ret=  282  daily=   829
# OK binance-peg-dogecoin  m5_ret=  281  daily=  1550
# OK global-dollar         m5_ret=  282  daily=   289
# OK decentraland          m5_ret=  283  daily=  2852
# OK bitcoin-cash-sv       m5_ret=  279  daily=  2476
# OK starknet              m5_ret=  284  daily=   548
# OK dydx-chain            m5_ret=  284  daily=   633
# OK beldex                m5_ret=  284  daily=  2469
# OK ether-fi              m5_ret=  283  daily=   521
# OK solv-protocol-solvbtc-bbn  m5_ret=  284  daily=   384
# OK true-usd              m5_ret=  282  daily=  2708
# OK helium                m5_ret=  281  daily=  1951
# OK based-brett           m5_ret=  282  daily=   539
# OK reserve-rights-token  m5_ret=  285  daily=  2282
# OK keeta                 m5_ret=  283  daily=   168
# OK frax-ether            m5_ret=  284  daily=   992
# OK apecoin               m5_ret=  281  daily=  1253
# OK usdd                  m5_ret=  282  daily=  1207
# OK coredaoorg            m5_ret=  281  daily=   925
# OK telcoin               m5_ret=  283  daily=  2756
# OK polygon-pos-bridged-weth-polygon-pos  m5_ret=  283  daily=   371
# OK syrup                 m5_ret=  283  daily=   281
# OK apenft                m5_ret=  282  daily=  1553
# OK thorchain             m5_ret=  283  daily=  2223
# OK zksync                m5_ret=  283  daily=   430
# OK arweave               m5_ret=  284  daily=  2120
# OK sun-token             m5_ret=  283  daily=  1805
# OK instadapp             m5_ret=  283  daily=  1527
# OK savings-dai           m5_ret=  279  daily=   679
# OK chain-2               m5_ret=  281  daily=  1255
# OK polygon-pos-bridged-dai-polygon-pos  m5_ret=  283  daily=   367
# OK compound-governance-token  m5_ret=  283  daily=  1892
# OK mantle-bridged-usdt-mantle  m5_ret=  283  daily=   561
# OK superstate-short-duration-us-government-securities-fund-ustb  m5_ret=  253  daily=   293
# OK neo                   m5_ret=  281  daily=  3265
# OK eigenlayer            m5_ret=  283  daily=   324
# OK elrond-erd-2          m5_ret=  283  daily=  1813
# OK hashnote-usyc         m5_ret=  176  daily=   280
# OK mog-coin              m5_ret=  281  daily=   762
# OK aioz-network          m5_ret=  282  daily=  1601
# OK bridged-usdc-polygon-pos-bridge  m5_ret=  282  daily=   644
# OK dexe                  m5_ret=  282  daily=  1780
# OK kava                  m5_ret=  283  daily=  2126
# OK tokenize-xchange      m5_ret=  282  daily=  2310
# OK usdb                  m5_ret=  280  daily=   538
# OK superfarm             m5_ret=  283  daily=  1641
# OK ecash                 m5_ret=  282  daily=  1511
# OK chiliz                m5_ret=  283  daily=  2242
# OK deep                  m5_ret=  283  daily=   311
# OK beam-2                m5_ret=  282  daily=   665
# OK rekt-4                m5_ret=  283  daily=   272
# OK treehouse-eth         m5_ret=  284  daily=   327
# OK axie-infinity         m5_ret=  283  daily=  1751
# OK bybit-staked-sol      m5_ret=  281  daily=   349
# OK zebec-network         m5_ret=  284  daily=   493
# OK wemix-token           m5_ret=  281  daily=  1754
# OK unit-bitcoin          m5_ret=  283  daily=   141
# OK olympus               m5_ret=  283  daily=  1611
# OK wormhole              m5_ret=  284  daily=   505
# OK aethir                m5_ret=  281  daily=   435
# OK wrapped-avax          m5_ret=  283  daily=  1574
# OK ronin                 m5_ret=  283  daily=  1302
# OK benqi-liquid-staked-avax  m5_ret=  281  daily=  1279
# OK wrapped-hype          m5_ret=  281  daily=   181
# OK creditcoin-2          m5_ret=  280  daily=  2023
# OK ether-fi-staked-btc   m5_ret=  283  daily=   325
# OK gho                   m5_ret=  281  daily=   768
# OK 1inch                 m5_ret=  281  daily=  1700
# OK qubic-network         m5_ret=  283  daily=   646
# OK movement              m5_ret=  282  daily=   255
# OK reserve-protocol-eth-plus  m5_ret=  283  daily=   455
# OK gnosis                m5_ret=  279  daily=  3032
# OK venom                 m5_ret=  282  daily=   514
# OK snek                  m5_ret=  281  daily=   822
# OK wrapped-ether-mantle-bridge  m5_ret=  280  daily=   764
# OK akash-network         m5_ret=  282  daily=  1769
# OK staked-frax-ether     m5_ret=  282  daily=   960
# OK matic-network         m5_ret=  283  daily=  2308
# OK drift-protocol        m5_ret=  281  daily=   462
# OK eutbl                 m5_ret=  245  daily=   371
# OK steakhouse-usdc-morpho-vault  m5_ret=  248  daily=   255
# OK terra-luna            m5_ret=  284  daily=  2297
# OK eos                   m5_ret=  282  daily=  2965
# OK just                  m5_ret=  281  daily=  1931
# OK polygon-bridged-wbtc-polygon-pos  m5_ret=  281  daily=   382
# OK convex-finance        m5_ret=  283  daily=  1557
# DAILY tail:
#                                   bitcoin     ethereum    ripple    tether  \
# timestamp
# 2025-08-16 00:00:00+00:00  117339.791902  4430.532465  3.077373  1.000653
# 2025-08-17 00:00:00+00:00  117501.216534  4426.826913  3.106969  1.000592
# 2025-08-18 00:00:00+00:00  117542.836878  4487.118014  3.095386  1.000641
# 2025-08-19 00:00:00+00:00  116256.412767  4317.275757  3.060621  1.000443
# 2025-08-20 00:00:00+00:00  113586.199449  4162.120586  2.894526  0.999940
#
#                            binancecoin      solana  usd-coin  staked-ether  \
# timestamp
# 2025-08-16 00:00:00+00:00   827.291681  185.599695  0.999807   4418.303777
# 2025-08-17 00:00:00+00:00   839.056661  189.769423  0.999903   4414.133653
# 2025-08-18 00:00:00+00:00   856.942456  191.640990  0.999901   4480.764614
# 2025-08-19 00:00:00+00:00   848.229879  183.013038  0.999812   4306.867740
# 2025-08-20 00:00:00+00:00   834.846108  180.147775  0.999799   4152.738403
#
#                                tron  dogecoin  ...  staked-frax-ether  \
# timestamp                                      ...
# 2025-08-16 00:00:00+00:00  0.352168  0.228213  ...        4985.281420
# 2025-08-17 00:00:00+00:00  0.348032  0.231019  ...        5006.873154
# 2025-08-18 00:00:00+00:00  0.353879  0.235436  ...        5069.668330
# 2025-08-19 00:00:00+00:00  0.350288  0.222461  ...        4861.083247
# 2025-08-20 00:00:00+00:00  0.348737  0.212482  ...        4690.381569
#
#                            matic-network  drift-protocol     eutbl  \
# timestamp
# 2025-08-16 00:00:00+00:00       0.232861        0.532233  1.214718
# 2025-08-17 00:00:00+00:00       0.236514        0.552602  1.214718
# 2025-08-18 00:00:00+00:00       0.247004        0.542003  1.214691
# 2025-08-19 00:00:00+00:00       0.257850        0.520200  1.210928
# 2025-08-20 00:00:00+00:00       0.237458        0.516451  1.207845
#
#                            steakhouse-usdc-morpho-vault  terra-luna       eos  \
# timestamp
# 2025-08-16 00:00:00+00:00                      1.096067    0.000059  0.504587
# 2025-08-17 00:00:00+00:00                      1.096187    0.000063  0.511414
# 2025-08-18 00:00:00+00:00                      1.096285    0.000062  0.512311
# 2025-08-19 00:00:00+00:00                      1.096278    0.000059  0.496354
# 2025-08-20 00:00:00+00:00                      1.096411    0.000058  0.489205
#
#                                just  polygon-bridged-wbtc-polygon-pos  \
# timestamp
# 2025-08-16 00:00:00+00:00  0.033277                     117135.611886
# 2025-08-17 00:00:00+00:00  0.033295                     117408.036837
# 2025-08-18 00:00:00+00:00  0.033538                     117494.609665
# 2025-08-19 00:00:00+00:00  0.032868                     116212.036487
# 2025-08-20 00:00:00+00:00  0.032469                     113587.573159
#
#                            convex-finance
# timestamp
# 2025-08-16 00:00:00+00:00        4.128444
# 2025-08-17 00:00:00+00:00        4.183225
# 2025-08-18 00:00:00+00:00        4.196860
# 2025-08-19 00:00:00+00:00        4.077602
# 2025-08-20 00:00:00+00:00        3.866414
#
# [5 rows x 250 columns]
# 5-MIN RETURNS tail:
#                              bitcoin  ethereum    ripple    tether  \
# timestamp
# 2025-08-20 05:20:00+00:00 -0.000143 -0.001753 -0.000655  0.000008
# 2025-08-20 05:25:00+00:00  0.000509  0.001124 -0.000024  0.000017
# 2025-08-20 05:30:00+00:00  0.000192  0.000349  0.000554 -0.000008
# 2025-08-20 05:35:00+00:00 -0.000005  0.000349 -0.000027 -0.000008
# 2025-08-20 05:40:00+00:00 -0.000005  0.000349 -0.000027 -0.000008
#
#                            binancecoin    solana  usd-coin  staked-ether  \
# timestamp
# 2025-08-20 05:20:00+00:00    -0.000370 -0.001112 -0.000008     -0.000932
# 2025-08-20 05:25:00+00:00    -0.000092 -0.000449  0.000042      0.000732
# 2025-08-20 05:30:00+00:00     0.000144  0.000696 -0.000002      0.000641
# 2025-08-20 05:35:00+00:00     0.000144  0.000696 -0.000002     -0.000084
# 2025-08-20 05:40:00+00:00     0.000144  0.000696 -0.000002     -0.000084
#
#                                tron  dogecoin  ...  staked-frax-ether  \
# timestamp                                      ...
# 2025-08-20 05:20:00+00:00  0.000022 -0.000761  ...          -0.007631
# 2025-08-20 05:25:00+00:00  0.000108 -0.000414  ...           0.000031
# 2025-08-20 05:30:00+00:00  0.000750  0.000189  ...           0.000043
# 2025-08-20 05:35:00+00:00  0.000201  0.000414  ...          -0.000019
# 2025-08-20 05:40:00+00:00  0.000201  0.000414  ...           0.002445
#
#                            matic-network  drift-protocol     eutbl  \
# timestamp
# 2025-08-20 05:20:00+00:00      -0.001495       -0.002162 -0.000009
# 2025-08-20 05:25:00+00:00      -0.002849        0.000606  0.000129
# 2025-08-20 05:30:00+00:00       0.001092        0.000712  0.000120
# 2025-08-20 05:35:00+00:00       0.001026        0.001443 -0.000002
# 2025-08-20 05:40:00+00:00       0.000491        0.000653 -0.000002
#
#                            steakhouse-usdc-morpho-vault  terra-luna  \
# timestamp
# 2025-08-20 05:20:00+00:00                     -0.000142   -0.000503
# 2025-08-20 05:25:00+00:00                      0.000234   -0.000148
# 2025-08-20 05:30:00+00:00                     -0.000057    0.000688
# 2025-08-20 05:35:00+00:00                      0.000069    0.000590
# 2025-08-20 05:40:00+00:00                     -0.000072    0.000140
#
#                                     eos      just  \
# timestamp
# 2025-08-20 05:20:00+00:00 -1.013497e-03 -0.000313
# 2025-08-20 05:25:00+00:00 -1.001074e-03  0.000492
# 2025-08-20 05:30:00+00:00 -3.729731e-07  0.000063
# 2025-08-20 05:35:00+00:00  1.850941e-03  0.000054
# 2025-08-20 05:40:00+00:00  1.439398e-03  0.000155
#
#                            polygon-bridged-wbtc-polygon-pos  convex-finance
# timestamp
# 2025-08-20 05:20:00+00:00                         -0.000046       -0.000794
# 2025-08-20 05:25:00+00:00                          0.000624       -0.000769
# 2025-08-20 05:30:00+00:00                          0.000566        0.001017
# 2025-08-20 05:35:00+00:00                         -0.000437        0.000609
# 2025-08-20 05:40:00+00:00                          0.000595        0.001496
#
# [5 rows x 250 columns]

# %%
#wide_daily.head()
#wide_daily.columns
#wide_5m_returns.head()
#wide_5m_returns.tail()
#wide_15m.columns
# Plain CSV (includes timestamp index as first column)
#wide_daily.to_csv("coingecko_daily_close_topN.csv", index=True, index_label="timestamp")
#wide_5m_returns.to_csv("coingecko_5min_returns_topN.csv", index=True, index_label="timestamp")

# %%
# Process 5 minute returns/prep for use in model

import numpy as np
from darts import TimeSeries
from darts.dataprocessing.transformers import Scaler, MissingValuesFiller
from darts.utils.timeseries_generation import datetime_attribute_timeseries as dt_attrs

# --- Assumptions ---
# wide_5m_returns: pandas DataFrame, index is 5-minute UTC timestamps,
# one column per coin (e.g., "bitcoin", "ethereum", ...), values are 5-min returns.
# If you have prices instead, change the comments accordingly.

# 0) Housekeeping: make sure the index is named and sorted
wide_5m_returns = wide_5m_returns.sort_index()
wide_5m_returns.index.name = "timestamp"

# wide_5m_returns: ensure UTC-naive DateTimeIndex (Darts requirement)
wide_5m_returns = wide_5m_returns.copy()

# If index isn't datetime yet, parse as UTC first
if not isinstance(wide_5m_returns.index, pd.DatetimeIndex):
    wide_5m_returns.index = pd.to_datetime(wide_5m_returns.index, utc=True)

# If tz-aware, convert to UTC then drop tz info
if wide_5m_returns.index.tz is not None:
    wide_5m_returns.index = (
        wide_5m_returns.index.tz_convert("UTC").tz_localize(None)
    )

# 1) Build per-coin TimeSeries list from WIDE data
series_list = []
coin_ids = list(wide_5m_returns.columns)
for coin in coin_ids:
    df_coin = wide_5m_returns[[coin]].reset_index().rename(columns={coin: "y"})
    # fill_missing_dates=True ensures a regular 5-min grid even if there were gaps
    ts = TimeSeries.from_dataframe(
        df_coin,
        time_col="timestamp",
        value_cols="y",
        fill_missing_dates=True,
        freq="5min",
    )
    series_list.append(ts)

# 2) Handle missing values in the target
# For RETURNS, a common choice is to fill missing with 0 (no move).
filler_y = MissingValuesFiller(fill="auto")  # uses pandas interpolate()
series_list = [filler_y.transform(ts) for ts in series_list]

# (If your target were PRICES, you’d more likely use forward-fill:
#   MissingValuesFiller(fill="ffill")
# )

# 3) Build past covariates per series (time-of-day & day-of-week)
#    We generate them on each series' own time index so they align perfectly.
covs_list = []
for s in series_list:
    tod = dt_attrs(s.time_index, attribute="hour", one_hot=True, dtype=np.float32)
    dow = dt_attrs(s.time_index, attribute="day_of_week", one_hot=True, dtype=np.float32)
    covs = tod.stack(dow)  # multivariate TimeSeries with all one-hot columns
    covs_list.append(covs)

# (Optional) You can add more past covariates here, e.g.:
# - minute-of-hour one-hot (attribute="minute")
# - rolling volatility computed from returns and wrapped into a TimeSeries
# Just ensure the covariates share the same time index as each target series.

# 4) Scale targets and covariates globally
#    Using a single scaler per “family” helps global models.
scaler_y = Scaler()   # targets (returns)
scaler_x = Scaler()   # covariates (one-hots)

series_list_scaled = scaler_y.fit_transform(series_list)
covs_list_scaled   = scaler_x.fit_transform(covs_list)

# %%
# Define model
from darts.models import TFTModel
from darts.utils.likelihood_models import QuantileRegression

H = 12         # horizon in steps (e.g., 12 * 5-min = next hour)
K = 400        # number of sampled paths per forecast
RANDOM_STATE = 42

# Simple, robust TFT; tune later
model = TFTModel(
    input_chunk_length=96,          # 8 hours of lookback
    output_chunk_length=H,
    hidden_size=32,
    lstm_layers=2,
    dropout=0.10,
    add_relative_index=True,
    likelihood=QuantileRegression(quantiles=[0.05, 0.5, 0.95]),
    batch_size=64,
    n_epochs=40,
    random_state=RANDOM_STATE,
)

# %%
# train the model
# Fit on scaled returns with scaled covariates (from your earlier code)
model.fit(series=series_list_scaled, past_covariates=covs_list_scaled, verbose=True)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 0      | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 42.5 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 896    | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 4.3 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 4.3 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 4.3 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 4.3 K  | train
# 10 | lstm_encoder                      | LSTM                             | 16.9 K | train
# 11 | lstm_decoder                      | LSTM                             | 16.9 K | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 2.2 K  | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 5.3 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 2.6 K  | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 2.2 K  | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 4.3 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 2.2 K  | train
# 18 | output_layer                      | Linear                           | 99     | train
# ------------------------------------------------------------------------------------------------
# 113 K     Trainable params
# 0         Non-trainable params
# 113 K     Total params
# 0.453     Total estimated model params size (MB)
# 637       Modules in train mode
# 0         Modules in eval mode
# c:\users\12064\documents\.venv\lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Training: |                                                                                                   …
# `Trainer.fit` stopped: `max_epochs=40` reached.
# TFTModel(output_chunk_shift=0, hidden_size=32, lstm_layers=2, num_attention_heads=4, full_attention=False, feed_forward=GatedResidualNetwork, dropout=0.1, hidden_continuous_size=8, categorical_embedding_sizes=None, add_relative_index=True, loss_fn=None, likelihood=QuantileRegression(quantiles=[0.05, 0.5, 0.95], prior_strength=1.0), norm_type=LayerNorm, use_static_covariates=True, input_chunk_length=96, output_chunk_length=12, batch_size=64, n_epochs=40, random_state=42)

# %%
# Helper functions to assit convert outputs into more tangible results
import numpy as np
import pandas as pd

# Uses your existing market_chart_close()
def get_last_price_usd(coin_id: str) -> float:
    df1 = market_chart_close(coin_id, days=1)  # last ~day
    if df1.empty:
        return np.nan
    return float(df1["close"].iloc[-1])

def summarize_paths_from_returns(returns_paths: np.ndarray, last_price: float):
    """
    returns_paths: shape (H, K) of *simple* returns (r_t)
    last_price:    current USD price

    Outputs dict with prob_up and summary stats in log space and USD.
    """
    # cumulative log-return on each path (robust composition)
    cum_log = np.sum(np.log1p(returns_paths), axis=0)   # (K,)
    prob_up = float((cum_log > 0).mean())

    # summary in log space
    p50_log = float(np.median(cum_log))
    p05_log = float(np.quantile(cum_log, 0.05))
    p95_log = float(np.quantile(cum_log, 0.95))
    exp_log = float(cum_log.mean())

    # translate to USD change on each path
    # price_T = last_price * exp(cum_log); USD_change = price_T - last_price
    usd_changes = last_price * (np.exp(cum_log) - 1.0)  # (K,)

    p50_usd = float(np.median(usd_changes))
    p05_usd = float(np.quantile(usd_changes, 0.05))
    p95_usd = float(np.quantile(usd_changes, 0.95))
    exp_usd = float(usd_changes.mean())

    return {
        "prob_up": prob_up,
        "exp_logret": exp_log,
        "p50_logret": p50_log,
        "p05_logret": p05_log,
        "p95_logret": p95_log,
        "exp_usd": exp_usd,
        "p50_usd": p50_usd,
        "p05_usd": p05_usd,
        "p95_usd": p95_usd,
    }

# %%
# Another set of helpers and a test run
def forecast_coin_summary(coin_id: str, idx: int) -> dict:
    """
    coin_id: coin string (e.g., 'bitcoin'), matching coin_ids[idx]
    idx:     index into series_list_scaled, covs_list_scaled

    Returns a dict with coin, last_price, and summary stats.
    """
    # 1) Predict K sampled paths in *scaled* space
    samples_scaled = model.predict(
        n=H,
        series=series_list_scaled[idx],
        past_covariates=covs_list_scaled[idx],
        num_samples=K,
        verbose=False,
    )
    # 2) Invert scaling back to RETURNS
    samples = scaler_y.inverse_transform(samples_scaled)

    # 3) Extract array: (H, 1, K) -> (H, K)
    arr = samples.all_values(copy=False)[:, 0, :]  # returns

    # 4) Latest price (USD)
    last_price = get_last_price_usd(coin_id)

    # 5) Summarize paths
    stats = summarize_paths_from_returns(arr, last_price)
    stats.update({"coin": coin_id, "last_price": float(last_price)})
    return stats

# Run for a few coins
summaries = []
for i, coin in enumerate(coin_ids[:20]):  # e.g., first 20
    try:
        summaries.append(forecast_coin_summary(coin, i))
    except Exception as e:
        print(f"ERR {coin}: {e}")

summary_df = pd.DataFrame(summaries).set_index("coin")
print(summary_df.head())
